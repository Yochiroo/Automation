# %%
CPO = [
  {
    "Désignation_Interne_TIMS": "CPO_SIEGE",
    "Magasin": "SIEGE",
    "LAN_VOIP": "172.17.254.0/24",
    "VLAN_SDSL": 3100,
    "Adressage_SDSL": "172.31.251.60/30",
    "Code Postal": ""
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLSTANDRE",
    "Magasin": "TLSTANDRE",
    "LAN_VOIP": "172.17.10.0/24",
    "VLAN_SDSL": 3110,
    "Adressage_SDSL": "172.31.250.0/30",
    "Code Postal": "01390"
  },
  {
    "Désignation_Interne_TIMS": "CPO_VIENNE",
    "Magasin": "VIENNE",
    "LAN_VOIP": "172.17.11.0/24",
    "VLAN_SDSL": 3111,
    "Adressage_SDSL": "172.31.250.4/30",
    "Code Postal": 38200
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLSTGEORGES",
    "Magasin": "TLSTGEORGES",
    "LAN_VOIP": "172.17.12.0/24",
    "VLAN_SDSL": 3112,
    "Adressage_SDSL": "172.31.250.8/30",
    "Code Postal": 38790
  },
  {
    "Désignation_Interne_TIMS": "CPO_FEURS",
    "Magasin": "FEURS",
    "LAN_VOIP": "172.17.13.0/24",
    "VLAN_SDSL": 3113,
    "Adressage_SDSL": "172.31.250.12/30",
    "Code Postal": 42110
  },
  {
    "Désignation_Interne_TIMS": "CPO_SCCHAZELLES",
    "Magasin": "SCCHAZELLES",
    "LAN_VOIP": "172.17.14.0/24",
    "VLAN_SDSL": 3114,
    "Adressage_SDSL": "172.31.250.16/30",
    "Code Postal": 42140
  },
  {
    "Désignation_Interne_TIMS": "CPO_CHARITE",
    "Magasin": "CHARITE",
    "LAN_VOIP": "172.17.15.0/24",
    "VLAN_SDSL": 3115,
    "Adressage_SDSL": "172.31.250.20/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_HOTELDIEU",
    "Magasin": "HOTELDIEU",
    "LAN_VOIP": "172.17.16.0/24",
    "VLAN_SDSL": 3116,
    "Adressage_SDSL": "172.31.250.24/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_RUEDEBREST",
    "Magasin": "RUEDEBREST",
    "LAN_VOIP": "172.17.17.0/24",
    "VLAN_SDSL": 3117,
    "Adressage_SDSL": "172.31.250.28/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_SAINTANTOINE",
    "Magasin": "SAINTANTOINE",
    "LAN_VOIP": "172.17.18.0/24",
    "VLAN_SDSL": 3118,
    "Adressage_SDSL": "172.31.250.32/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_VAUBECOUR",
    "Magasin": "VAUBECOUR",
    "LAN_VOIP": "172.17.19.0/24",
    "VLAN_SDSL": 3119,
    "Adressage_SDSL": "172.31.250.36/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_PERRACHE",
    "Magasin": "PERRACHE",
    "LAN_VOIP": "172.17.20.0/24",
    "VLAN_SDSL": 3120,
    "Adressage_SDSL": "172.31.250.40/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLFRANKLIN",
    "Magasin": "TLFRANKLIN",
    "LAN_VOIP": "172.17.21.0/24",
    "VLAN_SDSL": 3121,
    "Adressage_SDSL": "172.31.250.44/30",
    "Code Postal": 69002
  },
  {
    "Désignation_Interne_TIMS": "CPO_AUPTITJARDIN",
    "Magasin": "AUPTITJARDIN",
    "LAN_VOIP": "172.17.22.0/24",
    "VLAN_SDSL": 3122,
    "Adressage_SDSL": "172.31.250.48/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_LESHALLES",
    "Magasin": "LESHALLES",
    "LAN_VOIP": "172.17.23.0/24",
    "VLAN_SDSL": 3123,
    "Adressage_SDSL": "172.31.250.52/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_FRUISYGARIBALDI",
    "Magasin": "FRUISYGARIBALDI",
    "LAN_VOIP": "172.17.24.0/24",
    "VLAN_SDSL": 3124,
    "Adressage_SDSL": "172.31.250.56/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_CERISEETCREATION",
    "Magasin": "CERISEETCREATION",
    "LAN_VOIP": "172.17.25.0/24",
    "VLAN_SDSL": 3125,
    "Adressage_SDSL": "172.31.250.60/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_LACASSAGNE",
    "Magasin": "LACASSAGNE",
    "LAN_VOIP": "172.17.26.0/24",
    "VLAN_SDSL": 3126,
    "Adressage_SDSL": "172.31.250.64/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_LYON3",
    "Magasin": "LYON3",
    "LAN_VOIP": "172.17.27.0/24",
    "VLAN_SDSL": 3127,
    "Adressage_SDSL": "172.31.250.68/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLPLACERONDE",
    "Magasin": "TLPLACERONDE",
    "LAN_VOIP": "172.17.28.0/24",
    "VLAN_SDSL": 3128,
    "Adressage_SDSL": "172.31.250.72/30",
    "Code Postal": 69003
  },
  {
    "Désignation_Interne_TIMS": "CPO_CROIXROUSSE",
    "Magasin": "CROIXROUSSE",
    "LAN_VOIP": "172.17.29.0/24",
    "VLAN_SDSL": 3129,
    "Adressage_SDSL": "172.31.250.76/30",
    "Code Postal": 69004
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLCROIXROUSSE",
    "Magasin": "TLCROIXROUSSE",
    "LAN_VOIP": "172.17.30.0/24",
    "VLAN_SDSL": 3130,
    "Adressage_SDSL": "172.31.250.80/30",
    "Code Postal": 69004
  },
  {
    "Désignation_Interne_TIMS": "CPO_FULCHIRON",
    "Magasin": "FULCHIRON",
    "LAN_VOIP": "172.17.31.0/24",
    "VLAN_SDSL": 3131,
    "Adressage_SDSL": "172.31.250.84/30",
    "Code Postal": 69005
  },
  {
    "Désignation_Interne_TIMS": "CPO_POINTDUJOUR",
    "Magasin": "POINTDUJOUR",
    "LAN_VOIP": "172.17.32.0/24",
    "VLAN_SDSL": 3132,
    "Adressage_SDSL": "172.31.250.88/30",
    "Code Postal": 69005
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLMENIVAL",
    "Magasin": "TLMENIVAL",
    "LAN_VOIP": "172.17.33.0/24",
    "VLAN_SDSL": 3133,
    "Adressage_SDSL": "172.31.250.92/30",
    "Code Postal": 69005
  },
  {
    "Désignation_Interne_TIMS": "CPO_BROTTEAUX",
    "Magasin": "BROTTEAUX",
    "LAN_VOIP": "172.17.34.0/24",
    "VLAN_SDSL": 3134,
    "Adressage_SDSL": "172.31.250.96/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_FOCH",
    "Magasin": "FOCH",
    "LAN_VOIP": "172.17.35.0/24",
    "VLAN_SDSL": 3135,
    "Adressage_SDSL": "172.31.250.100/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_SULLY-LYON6",
    "Magasin": "SULLY-LYON6",
    "LAN_VOIP": "172.17.36.0/24",
    "VLAN_SDSL": 3136,
    "Adressage_SDSL": "172.31.250.104/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_TETEDOR",
    "Magasin": "TETEDOR",
    "LAN_VOIP": "172.17.37.0/24",
    "VLAN_SDSL": 3137,
    "Adressage_SDSL": "172.31.250.108/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLBUGEAUD",
    "Magasin": "TLBUGEAUD",
    "LAN_VOIP": "172.17.38.0/24",
    "VLAN_SDSL": 3138,
    "Adressage_SDSL": "172.31.250.112/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLVITTON",
    "Magasin": "TLVITTON",
    "LAN_VOIP": "172.17.39.0/24",
    "VLAN_SDSL": 3139,
    "Adressage_SDSL": "172.31.250.116/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_SARRAIL",
    "Magasin": "SARRAIL",
    "LAN_VOIP": "172.17.40.0/24",
    "VLAN_SDSL": 3140,
    "Adressage_SDSL": "172.31.250.120/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_MDS",
    "Magasin": "MDS",
    "LAN_VOIP": "172.17.41.0/24",
    "VLAN_SDSL": 3141,
    "Adressage_SDSL": "172.31.250.124/30",
    "Code Postal": 69006
  },
  {
    "Désignation_Interne_TIMS": "CPO_JAURES",
    "Magasin": "JAURES",
    "LAN_VOIP": "172.17.42.0/24",
    "VLAN_SDSL": 3142,
    "Adressage_SDSL": "172.31.250.128/30",
    "Code Postal": 69007
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLJAURES",
    "Magasin": "TLJAURES",
    "LAN_VOIP": "172.17.43.0/24",
    "VLAN_SDSL": 3143,
    "Adressage_SDSL": "172.31.250.132/30",
    "Code Postal": 69007
  },
  {
    "Désignation_Interne_TIMS": "CPO_MONPLAISIR",
    "Magasin": "MONPLAISIR",
    "LAN_VOIP": "172.17.44.0/24",
    "VLAN_SDSL": 3144,
    "Adressage_SDSL": "172.31.250.136/30",
    "Code Postal": 69008
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLFRERESLUMIERE",
    "Magasin": "TLFRERESLUMIERE",
    "LAN_VOIP": "172.17.45.0/24",
    "VLAN_SDSL": 3145,
    "Adressage_SDSL": "172.31.250.140/30",
    "Code Postal": 69008
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLSTPIERREDEVAISE",
    "Magasin": "TLSTPIERREDEVAISE",
    "LAN_VOIP": "172.17.46.0/24",
    "VLAN_SDSL": 3146,
    "Adressage_SDSL": "172.31.250.144/30",
    "Code Postal": 69009
  },
  {
    "Désignation_Interne_TIMS": "CPO_VAISEDOCKS",
    "Magasin": "VAISEDOCKS",
    "LAN_VOIP": "172.17.47.0/24",
    "VLAN_SDSL": 3147,
    "Adressage_SDSL": "172.31.250.148/30",
    "Code Postal": 69009
  },
  {
    "Désignation_Interne_TIMS": "CPO_CHARPENNES",
    "Magasin": "CHARPENNES",
    "LAN_VOIP": "172.17.48.0/24",
    "VLAN_SDSL": 3148,
    "Adressage_SDSL": "172.31.250.152/30",
    "Code Postal": 69100
  },
  {
    "Désignation_Interne_TIMS": "CPO_GRATTECIEL",
    "Magasin": "GRATTECIEL",
    "LAN_VOIP": "172.17.49.0/24",
    "VLAN_SDSL": 3149,
    "Adressage_SDSL": "172.31.250.156/30",
    "Code Postal": 69100
  },
  {
    "Désignation_Interne_TIMS": "CPO_STEFOYLESLYON",
    "Magasin": "STEFOYLESLYON",
    "LAN_VOIP": "172.17.50.0/24",
    "VLAN_SDSL": 3150,
    "Adressage_SDSL": "172.31.250.160/30",
    "Code Postal": 69110
  },
  {
    "Désignation_Interne_TIMS": "CPO_ECULLY",
    "Magasin": "ECULLY",
    "LAN_VOIP": "172.17.51.0/24",
    "VLAN_SDSL": 3151,
    "Adressage_SDSL": "172.31.250.164/30",
    "Code Postal": 69130
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLGENAE-LEPEROLLIER",
    "Magasin": "TLGENAE-LEPEROLLIER",
    "LAN_VOIP": "172.17.52.0/24",
    "VLAN_SDSL": 3152,
    "Adressage_SDSL": "172.31.250.168/30",
    "Code Postal": 69130
  },
  {
    "Désignation_Interne_TIMS": "CPO_TASSIN",
    "Magasin": "TASSIN",
    "LAN_VOIP": "172.17.53.0/24",
    "VLAN_SDSL": 3153,
    "Adressage_SDSL": "172.31.250.172/30",
    "Code Postal": 69160
  },
  {
    "Désignation_Interne_TIMS": "CPO_TARARE",
    "Magasin": "TARARE",
    "LAN_VOIP": "172.17.54.0/24",
    "VLAN_SDSL": 3154,
    "Adressage_SDSL": "172.31.250.176/30",
    "Code Postal": 69170
  },
  {
    "Désignation_Interne_TIMS": "CPO_FLEURIEUX",
    "Magasin": "FLEURIEUX",
    "LAN_VOIP": "172.17.55.0/24",
    "VLAN_SDSL": 3155,
    "Adressage_SDSL": "172.31.250.180/30",
    "Code Postal": 69210
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLLARBRESLE",
    "Magasin": "TLLARBRESLE",
    "LAN_VOIP": "172.17.56.0/24",
    "VLAN_SDSL": 3156,
    "Adressage_SDSL": "172.31.250.184/30",
    "Code Postal": 69210
  },
  {
    "Désignation_Interne_TIMS": "CPO_BELLEVILLE",
    "Magasin": "BELLEVILLE",
    "LAN_VOIP": "172.17.57.0/24",
    "VLAN_SDSL": 3157,
    "Adressage_SDSL": "172.31.250.188/30",
    "Code Postal": 69220
  },
  {
    "Désignation_Interne_TIMS": "CPO_SAINTGENIS",
    "Magasin": "SAINTGENIS",
    "LAN_VOIP": "172.17.58.0/24",
    "VLAN_SDSL": 3158,
    "Adressage_SDSL": "172.31.250.192/30",
    "Code Postal": 69230
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLSTGENIS2",
    "Magasin": "TLSTGENIS2",
    "LAN_VOIP": "172.17.59.0/24",
    "VLAN_SDSL": 3159,
    "Adressage_SDSL": "172.31.250.196/30",
    "Code Postal": 69230
  },
  {
    "Désignation_Interne_TIMS": "CPO_NEUVILLE",
    "Magasin": "NEUVILLE",
    "LAN_VOIP": "172.17.60.0/24",
    "VLAN_SDSL": 3160,
    "Adressage_SDSL": "172.31.250.200/30",
    "Code Postal": 69250
  },
  {
    "Désignation_Interne_TIMS": "CPO_CHARBONNIERES",
    "Magasin": "CHARBONNIERES",
    "LAN_VOIP": "172.17.61.0/24",
    "VLAN_SDSL": 3161,
    "Adressage_SDSL": "172.31.250.204/30",
    "Code Postal": 69260
  },
  {
    "Désignation_Interne_TIMS": "CPO_HALLESDELOUEST",
    "Magasin": "HALLESDELOUEST",
    "LAN_VOIP": "172.17.62.0/24",
    "VLAN_SDSL": 3162,
    "Adressage_SDSL": "172.31.250.208/30",
    "Code Postal": 69260
  },
  {
    "Désignation_Interne_TIMS": "CPO_CRAPONNE",
    "Magasin": "CRAPONNE",
    "LAN_VOIP": "172.17.63.0/24",
    "VLAN_SDSL": 3163,
    "Adressage_SDSL": "172.31.250.212/30",
    "Code Postal": 69290
  },
  {
    "Désignation_Interne_TIMS": "CPO_CALUIRE2",
    "Magasin": "CALUIRE2",
    "LAN_VOIP": "172.17.64.0/24",
    "VLAN_SDSL": 3164,
    "Adressage_SDSL": "172.31.250.216/30",
    "Code Postal": 69300
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLJONAGE",
    "Magasin": "TLJONAGE",
    "LAN_VOIP": "172.17.65.0/24",
    "VLAN_SDSL": 3165,
    "Adressage_SDSL": "172.31.250.220/30",
    "Code Postal": 69330
  },
  {
    "Désignation_Interne_TIMS": "CPO_STDIDIER",
    "Magasin": "STDIDIER",
    "LAN_VOIP": "172.17.66.0/24",
    "VLAN_SDSL": 3166,
    "Adressage_SDSL": "172.31.250.224/30",
    "Code Postal": 69370
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLCHATILLON",
    "Magasin": "TLCHATILLON",
    "LAN_VOIP": "172.17.67.0/24",
    "VLAN_SDSL": 3167,
    "Adressage_SDSL": "172.31.250.228/30",
    "Code Postal": 69380
  },
  {
    "Désignation_Interne_TIMS": "CPO_SCIONZIER",
    "Magasin": "SCIONZIER",
    "LAN_VOIP": "172.17.68.0/24",
    "VLAN_SDSL": 3168,
    "Adressage_SDSL": "172.31.250.232/30",
    "Code Postal": 69380
  },
  {
    "Désignation_Interne_TIMS": "CPO_BEAUJOLAIS",
    "Magasin": "BEAUJOLAIS",
    "LAN_VOIP": "172.17.69.0/24",
    "VLAN_SDSL": 3169,
    "Adressage_SDSL": "172.31.250.236/30",
    "Code Postal": 69400
  },
  {
    "Désignation_Interne_TIMS": "CPO_RUENATIONALE",
    "Magasin": "RUENATIONALE",
    "LAN_VOIP": "172.17.70.0/24",
    "VLAN_SDSL": 3170,
    "Adressage_SDSL": "172.31.250.240/30",
    "Code Postal": 69400
  },
  {
    "Désignation_Interne_TIMS": "CPO_CHAMPAGNE",
    "Magasin": "CHAMPAGNE",
    "LAN_VOIP": "172.17.71.0/24",
    "VLAN_SDSL": 3171,
    "Adressage_SDSL": "172.31.250.244/30",
    "Code Postal": 69410
  },
  {
    "Désignation_Interne_TIMS": "CPO_TLBRON",
    "Magasin": "TLBRON",
    "LAN_VOIP": "172.17.72.0/24",
    "VLAN_SDSL": 3172,
    "Adressage_SDSL": "172.31.250.248/30",
    "Code Postal": 69500
  },
  {
    "Désignation_Interne_TIMS": "CPO_OULLINS",
    "Magasin": "OULLINS",
    "LAN_VOIP": "172.17.73.0/24",
    "VLAN_SDSL": 3173,
    "Adressage_SDSL": "172.31.250.252/30",
    "Code Postal": 69600
  },
  {
    "Désignation_Interne_TIMS": "CPO_OULLINS2",
    "Magasin": "OULLINS2",
    "LAN_VOIP": "172.17.74.0/24",
    "VLAN_SDSL": 3174,
    "Adressage_SDSL": "172.31.251.0/30",
    "Code Postal": 69600
  },
  {
    "Désignation_Interne_TIMS": "CPO_GENAS",
    "Magasin": "GENAS",
    "LAN_VOIP": "172.17.75.0/24",
    "VLAN_SDSL": 3175,
    "Adressage_SDSL": "172.31.251.4/30",
    "Code Postal": 69740
  },
  {
    "Désignation_Interne_TIMS": "CPO_LAHALLERN6",
    "Magasin": "LAHALLERN6",
    "LAN_VOIP": "172.17.76.0/24",
    "VLAN_SDSL": 3176,
    "Adressage_SDSL": "172.31.251.8/30",
    "Code Postal": 69800
  },
  {
    "Désignation_Interne_TIMS": "CPO_CHAMBERY",
    "Magasin": "CHAMBERY",
    "LAN_VOIP": "172.17.77.0/24",
    "VLAN_SDSL": 3177,
    "Adressage_SDSL": "172.31.251.12/30",
    "Code Postal": 73000
  },
  {
    "Désignation_Interne_TIMS": "CPO_AIX1",
    "Magasin": "AIX1",
    "LAN_VOIP": "172.17.78.0/24",
    "VLAN_SDSL": 3178,
    "Adressage_SDSL": "172.31.251.16/30",
    "Code Postal": 73100
  },
  {
    "Désignation_Interne_TIMS": "CPO_AIX2",
    "Magasin": "AIX2",
    "LAN_VOIP": "172.17.79.0/24",
    "VLAN_SDSL": 3179,
    "Adressage_SDSL": "172.31.251.20/30",
    "Code Postal": 73100
  },
  {
    "Désignation_Interne_TIMS": "CPO_GRESY-SUR-AIX",
    "Magasin": "GRESY-SUR-AIX",
    "LAN_VOIP": "172.17.80.0/24",
    "VLAN_SDSL": 3180,
    "Adressage_SDSL": "172.31.251.24/30",
    "Code Postal": 73100
  },
  {
    "Désignation_Interne_TIMS": "CPO_ALBERTVILLE",
    "Magasin": "ALBERTVILLE",
    "LAN_VOIP": "172.17.81.0/24",
    "VLAN_SDSL": 3181,
    "Adressage_SDSL": "172.31.251.28/30",
    "Code Postal": 73200
  },
  {
    "Désignation_Interne_TIMS": "CPO_AUX4SAISONS",
    "Magasin": "AUX4SAISONS",
    "LAN_VOIP": "172.17.82.0/24",
    "VLAN_SDSL": 3182,
    "Adressage_SDSL": "172.31.251.32/30",
    "Code Postal": 74000
  },
  {
    "Désignation_Interne_TIMS": "CPO_LAMANNE",
    "Magasin": "LAMANNE",
    "LAN_VOIP": "172.17.83.0/24",
    "VLAN_SDSL": 3183,
    "Adressage_SDSL": "172.31.251.36/30",
    "Code Postal": 74000
  },
  {
    "Désignation_Interne_TIMS": "CPO_NOVEL",
    "Magasin": "NOVEL",
    "LAN_VOIP": "172.17.84.0/24",
    "VLAN_SDSL": 3184,
    "Adressage_SDSL": "172.31.251.40/30",
    "Code Postal": 74000
  },
  {
    "Désignation_Interne_TIMS": "CPO_DOUVAINE",
    "Magasin": "DOUVAINE",
    "LAN_VOIP": "172.17.85.0/24",
    "VLAN_SDSL": 3185,
    "Adressage_SDSL": "172.31.251.44/30",
    "Code Postal": 74140
  },
  {
    "Désignation_Interne_TIMS": "CPO_HALLESTHONON",
    "Magasin": "HALLESTHONON",
    "LAN_VOIP": "172.17.86.0/24",
    "VLAN_SDSL": 3186,
    "Adressage_SDSL": "172.31.251.48/30",
    "Code Postal": 74200
  },
  {
    "Désignation_Interne_TIMS": "CPO_EVIAN",
    "Magasin": "EVIAN",
    "LAN_VOIP": "172.17.87.0/24",
    "VLAN_SDSL": 3187,
    "Adressage_SDSL": "172.31.251.52/30",
    "Code Postal": 74500
  },
  {
    "Désignation_Interne_TIMS": "CPO_ALBIGNY",
    "Magasin": "ALBIGNY",
    "LAN_VOIP": "172.17.88.0/24",
    "VLAN_SDSL": 3188,
    "Adressage_SDSL": "172.31.251.56/30",
    "Code Postal": 74940
  },
  {
    "Désignation_Interne_TIMS": "CPO_DUQUESNE",
    "Magasin": "DUQUESNE",
    "LAN_VOIP": "172.17.89.0/25",
    "VLAN_SDSL": 3189,
    "Adressage_SDSL": "172.31.251.64/30",
    "Code Postal": ""
  }
  
]

# %% [markdown]
# /interface vlan
# add interface=CPO-SITES-BK-ICO-TOIP name=CPO_SIEGE_VL3100 vlan-id=3100
# /ip pool
# add name=SIEGE_POOL ranges=172.17.254.100-172.17.254.199
# /ip dhcp-server
# add address-pool=SIEGE_POOL conflict-detection=no disabled=no interface=CPO_SIEGE_VL3100 name=SIEGE_DHCP relay=172.31.251.61
# /ip address
# add address=172.31.251.62/30 interface=CPO_SIEGE_VL3100
# /ip dhcp-server network
# add address=172.17.254.0/24 dhcp-option=Avaya_config dns-server=172.27.254.254,8.8.4.4 gateway=172.17.254.254 netmask=24
# /ip route
# add comment=SIEGE distance=1 dst-address=172.17.254.0/24 gateway=172.31.251.61

# %%
for s in CPO:
    # Generate all variables for microtik
    name = s['Désignation_Interne_TIMS'] + '_VL' + str(s['VLAN_SDSL'])
    # Ranges are set by using 3 1st bytes from IP
    pool = s['Magasin'] + '_POOL'
    dhcp = s['Magasin'] + '_DHCP'
    ranges = s['LAN_VOIP'][0:10] + '100-' + s['LAN_VOIP'][0:10] + '199'
    vlan_id = s['VLAN_SDSL']
    lan_voip = s['LAN_VOIP']
    print(name, ranges, vlan_id, pool, dhcp, lan_voip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 for s in CPO:
#       2     # Generate all variables for microtik
#       3     name = s['Désignation_Interne_TIMS'] + '_VL' + str(s['VLAN_SDSL'])
#       4     # Ranges are set by using 3 1st bytes from IP
#
# NameError: name 'CPO' is not defined
